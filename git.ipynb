# %% [markdown]
# <a href="https://colab.research.google.com/github/smish003/Comprehensive-Data-Analysis-and-Visualization-for-Identifying-Tuberculosis-Trends-and-Patterns/blob/main/git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello Wworld')
# Out:
# hello Wworld
